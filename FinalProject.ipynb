# %% [markdown]
# #### FINAL PROJECT DATA SCIEMCE ID/X PARTNERS

# %%
import pandas as pd
import numpy as np

# %%
payment.all()
# Out:
# id                   True
# member_id            True
# loan_amnt            True
# funded_amnt          True
# funded_amnt_inv     False
#                     ...
# all_util             True
# total_rev_hi_lim    False
# inq_fi               True
# total_cu_tl          True
# inq_last_12m         True
# Length: 74, dtype: bool

# %%
payment = pd.read_csv("loan_data.csv", index_col=0)
payment.head()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_5988\618102593.py:1: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   payment = pd.read_csv("loan_data.csv", index_col=0)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#    int_rate  installment grade sub_grade  ... total_bal_il il_util  \
# 0     10.65       162.87     B        B2  ...          NaN     NaN
# 1     15.27        59.83     C        C4  ...          NaN     NaN
# 2     15.96        84.33     C        C5  ...          NaN     NaN
# ...

# %%
payment.tail()
# Out:
#              id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 466280  8598660    1440975      18400        18400          18400.0
# 466281  9684700   11536848      22000        22000          22000.0
# 466282  9584776   11436914      20700        20700          20700.0
# 466283  9604874   11457002       2000         2000           2000.0
# 466284  9199665   11061576      10000        10000           9975.0
#
#               term  int_rate  installment grade sub_grade  ... total_bal_il  \
# 466280   60 months     14.47       432.64     C        C2  ...          NaN
# 466281   60 months     19.97       582.50     D        D5  ...          NaN
# 466282   60 months     16.99       514.34     D        D1  ...          NaN
# 466283   36 months      7.90        62.59     A        A4  ...          NaN
# 466284   36 months     19.20       367.58     D        D3  ...          NaN
#
#        il_util open_rv_12m  open_rv_24m max_bal_bc all_util total_rev_hi_lim  \
# ...

# %%
payment.describe()
# Out:
#                  id     member_id      loan_amnt    funded_amnt  \
# count  4.662850e+05  4.662850e+05  466285.000000  466285.000000
# mean   1.307973e+07  1.459766e+07   14317.277577   14291.801044
# std    1.089371e+07  1.168237e+07    8286.509164    8274.371300
# min    5.473400e+04  7.047300e+04     500.000000     500.000000
# 25%    3.639987e+06  4.379705e+06    8000.000000    8000.000000
# 50%    1.010790e+07  1.194108e+07   12000.000000   12000.000000
# 75%    2.073121e+07  2.300154e+07   20000.000000   20000.000000
# max    3.809811e+07  4.086083e+07   35000.000000   35000.000000
#
#        funded_amnt_inv       int_rate    installment    annual_inc  \
# count    466285.000000  466285.000000  466285.000000  4.662810e+05
# mean      14222.329888      13.829236     432.061201  7.327738e+04
# std        8297.637788       4.357587     243.485550  5.496357e+04
# min           0.000000       5.420000      15.670000  1.896000e+03
# ...

# %%
payment.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'next_pymnt_d', 'last_credit_pull_d', 'collections_12_mths_ex_med',
#        'mths_since_last_major_derog', 'policy_code', 'application_type',
# ...

# %%
total = payment.isnull().sum().sort_values(ascending=False)
percent = (payment.isnull().sum()/payment.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                               Total   Percent
# inq_last_12m                 466285  1.000000
# verification_status_joint    466285  1.000000
# open_acc_6m                  466285  1.000000
# open_il_6m                   466285  1.000000
# open_il_12m                  466285  1.000000
# open_il_24m                  466285  1.000000
# mths_since_rcnt_il           466285  1.000000
# dti_joint                    466285  1.000000
# total_bal_il                 466285  1.000000
# annual_inc_joint             466285  1.000000
# il_util                      466285  1.000000
# open_rv_12m                  466285  1.000000
# open_rv_24m                  466285  1.000000
# max_bal_bc                   466285  1.000000
# all_util                     466285  1.000000
# inq_fi                       466285  1.000000
# total_cu_tl                  466285  1.000000
# mths_since_last_record       403647  0.865666
# mths_since_last_major_derog  367311  0.787739
# ...

# %%
num_cols = payment._get_numeric_data().columns
payment_numeric = payment[num_cols]
payment_numeric.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# 0  1077501    1296599       5000         5000           4975.0     10.65
# 1  1077430    1314167       2500         2500           2500.0     15.27
# 2  1077175    1313524       2400         2400           2400.0     15.96
# 3  1076863    1277178      10000        10000          10000.0     13.49
# 4  1075358    1311748       3000         3000           3000.0     12.69
#
#    installment  annual_inc    dti  delinq_2yrs  ...  total_bal_il  il_util  \
# 0       162.87     24000.0  27.65          0.0  ...           NaN      NaN
# 1        59.83     30000.0   1.00          0.0  ...           NaN      NaN
# 2        84.33     12252.0   8.72          0.0  ...           NaN      NaN
# 3       339.31     49200.0  20.00          0.0  ...           NaN      NaN
# 4        67.79     80000.0  17.94          0.0  ...           NaN      NaN
#
# ...

# %%
payment_categorical = payment.drop(num_cols, axis = 1)
payment_categorical.head()
# Out:
#          term grade sub_grade                 emp_title emp_length  \
# 0   36 months     B        B2                       NaN  10+ years
# 1   60 months     C        C4                     Ryder   < 1 year
# 2   36 months     C        C5                       NaN  10+ years
# 3   36 months     C        C1       AIR RESOURCES BOARD  10+ years
# 4   60 months     B        B5  University Medical Group     1 year
#
#   home_ownership verification_status issue_d  loan_status pymnt_plan  ...  \
# 0           RENT            Verified  Dec-11   Fully Paid          n  ...
# 1           RENT     Source Verified  Dec-11  Charged Off          n  ...
# 2           RENT        Not Verified  Dec-11   Fully Paid          n  ...
# 3           RENT     Source Verified  Dec-11   Fully Paid          n  ...
# 4           RENT     Source Verified  Dec-11      Current          n  ...
#
#           purpose                 title zip_code addr_state earliest_cr_line  \
# ...

# %%
payment.isna()
# Out:
#            id  member_id  loan_amnt  funded_amnt  funded_amnt_inv   term  \
# 0       False      False      False        False            False  False
# 1       False      False      False        False            False  False
# 2       False      False      False        False            False  False
# 3       False      False      False        False            False  False
# 4       False      False      False        False            False  False
# ...       ...        ...        ...          ...              ...    ...
# 466280  False      False      False        False            False  False
# 466281  False      False      False        False            False  False
# 466282  False      False      False        False            False  False
# 466283  False      False      False        False            False  False
# 466284  False      False      False        False            False  False
#
#         int_rate  installment  grade  sub_grade  ...  total_bal_il  il_util  \
# ...

# %%
payment.notna()
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0       True       True       True         True             True  True
# 1       True       True       True         True             True  True
# 2       True       True       True         True             True  True
# 3       True       True       True         True             True  True
# 4       True       True       True         True             True  True
# ...      ...        ...        ...          ...              ...   ...
# 466280  True       True       True         True             True  True
# 466281  True       True       True         True             True  True
# 466282  True       True       True         True             True  True
# 466283  True       True       True         True             True  True
# 466284  True       True       True         True             True  True
#
#         int_rate  installment  grade  sub_grade  ...  total_bal_il  il_util  \
# ...

# %%
payment.isna().sum()
# Out:
# id                       0
# member_id                0
# loan_amnt                0
# funded_amnt              0
# funded_amnt_inv          0
#                      ...
# all_util            466285
# total_rev_hi_lim     70276
# inq_fi              466285
# total_cu_tl         466285
# inq_last_12m        466285
# Length: 74, dtype: int64

# %%
payment.shape
# Out:
# (466285, 74)

# %%
payment.dtypes
# Out:
# id                    int64
# member_id             int64
# loan_amnt             int64
# funded_amnt           int64
# funded_amnt_inv     float64
#                      ...
# all_util            float64
# total_rev_hi_lim    float64
# inq_fi              float64
# total_cu_tl         float64
# inq_last_12m        float64
# Length: 74, dtype: object
